# %%
import json
import os
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import keras
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from keras.layers import merge
from keras.layers.core import *
from keras.layers import LSTM
from keras.models import *

import numpy
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense,Merge
from keras.layers import LSTM,RepeatVector
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

import gensim
from gensim.scripts.glove2word2vec import glove2word2vec
import gensim.models.keyedvectors as word2vec
from gensim.models.keyedvectors import KeyedVectors

# %%
glove2word2vec(glove_input_file="glove.6B.50d.txt", word2vec_output_file="gensim_glove_vectors.txt")
glove_model = KeyedVectors.load_word2vec_format("gensim_glove_vectors.txt", binary=False)

# %%
def filter_sentence(text):
    #tokenizer = RegexpTokenizer(r'\w+')
    tokenizer = RegexpTokenizer(r'[A-z]+')
    stop_words = set(stopwords.words('english'))
    word_tokens = [string.lower() for string in tokenizer.tokenize(text)]
    #word_tokens = [w for w in word_tokens if not w in stop_words]
    #word_tokens = [w for w in word_tokens if len(w)>2]
    return word_tokens

# %%
def get_pd_frame_by_topics(topics):
    folder_names = topics
    

    non_rumour_json_obj = []
    for name in folder_names:
        non_rumours_paths = "pheme-rnr-dataset/"+name+"/non-rumours/"
        non_rumours_path = [x for x in os.listdir(non_rumours_paths)]
        for subfolder in non_rumours_path:
            subfolder_path = non_rumours_paths + subfolder + "/source-tweet/"
            json_files = [pos_json for pos_json in os.listdir(subfolder_path) if pos_json.endswith('.json')]
            for json_file in json_files:
                json_file_path = subfolder_path + json_file
                #print(json_file_path)
                with open(json_file_path) as json_data:
                    d = json.load(json_data)
                    non_rumour_json_obj.append(d)
    rumour_json_obj = []
    for name in folder_names:
        rumours_paths = "pheme-rnr-dataset/"+name+"/rumours/"
        rumours_path = [x for x in os.listdir(rumours_paths)]
        for subfolder in rumours_path:
            subfolder_path = rumours_paths + subfolder + "/source-tweet/"
            json_files = [pos_json for pos_json in os.listdir(subfolder_path) if pos_json.endswith('.json')]
            for json_file in json_files:
                json_file_path = subfolder_path + json_file
                #print(json_file_path)
                with open(json_file_path) as json_data:
                    d = json.load(json_data)
                    rumour_json_obj.append(d)


    retweet_count = []
    text = []
    created = []
    followers_count = []
    verified = []
    statuses_count = []
    user_age = []
    rumour = []

    for elem in non_rumour_json_obj:
        retweet_count.append(elem['retweet_count'])
        text.append(elem['text'])
        created.append(elem['created_at'])
        followers_count.append(elem['user']['followers_count'])
        verified.append(elem['user']['verified'])
        statuses_count.append(elem['user']['statuses_count'])
        user_age.append(elem['user']['created_at'])
        rumour.append('non_rumour')
    for elem in rumour_json_obj:
        retweet_count.append(elem['retweet_count'])
        text.append(elem['text'])
        created.append(elem['created_at'])
        followers_count.append(elem['user']['followers_count'])
        verified.append(elem['user']['verified'])
        statuses_count.append(elem['user']['statuses_count'])
        user_age.append(elem['user']['created_at'])
        rumour.append('rumour')


    df_temp = pd.DataFrame()
    df = pd.DataFrame()

    df_temp['retweet_count'] = retweet_count
    df_temp['text'] = text
    df_temp['created'] = created
    df_temp['followers_count'] = followers_count
    df_temp['verified'] = verified
    df_temp['statuses_count'] = statuses_count
    df_temp['user_age'] = user_age
    df_temp['rumour'] = rumour


    df.count()
    df_temp.to_csv('/home/dell/rumour.csv',sep=',')

    temp = pd.to_datetime(df_temp.created, format='%a %b %d %H:%M:%S +0000 %Y')

    df_temp = df_temp.sort_values(by='created')

    le = preprocessing.LabelEncoder()
    df_temp['verified_bool'] = le.fit_transform(df_temp['verified'])
    df_temp['rumour_bool'] = le.fit_transform(df_temp['rumour'])
    actual_labels = df_temp['rumour_bool']

    df = df_temp[['retweet_count','followers_count','verified_bool','statuses_count']]
    return df,df_temp

# %%
def convert_text_to_tokens(text,glove_model):
    tokens = []
    for t in text:
        token_line = filter_sentence(t)
        tokens.append(token_line)
    word_features = []

    not_found = 0
    text_features = []
    for token_line in tokens:
        line = []
        for token in token_line:
                try: 
                    word_vector = glove_model.get_vector(token)
                    line.append(word_vector)
                except:
                    not_found = not_found + 1
        text_features.append(line)

    # ##take average of features
    # avg_text_features = []
    # for lines in text_features:
    #     avg = np.zeros(50)
    #     count = 0
    #     for line in lines:
    #         avg = avg + line
    #         count = count + 1
    #     avg_text_features.append(avg)
    # word_avg_features = np.array(avg_text_features)
    # concat_features = np.concatenate((word_avg_features,df_text.as_matrix()),axis=1)

    lengths = []
    for line in text_features:
        lengths.append(len(line))
    print(max(lengths))


    lengths = []
    training_list_embedded = np.zeros(shape=(len(text_features),50,20))
    for i in range(len(text_features)):
        sentence = text_features[i]
        length = len(sentence)
        padded_sequence = []
        j = 1

        while(1):
                #print(j)
                if j>(20-length):
                    break
                padded_sequence.append(np.zeros(50))
                j = j + 1
        sentence = padded_sequence + sentence 
        training_list_embedded[i,:,:] = np.array(sentence).transpose()[:,:20]
    return training_list_embedded

# %%
####LSTM approach
def stacked_lstm(X_train,y_train,bsize):
    length =int(len(X_train)/bsize)*bsize


    # create the model
    inp1 = Input(batch_shape=(bsize,50,20),name='input1')
    input1 = Permute((2,1))(inp1)
    m1 = LSTM(20,input_shape=(20,50),stateful=True,batch_size=bsize,name='model1',recurrent_dropout=0.5)(input1)
    
    inp2 = Input(batch_shape=(bsize,50,20),name='input2')
    input2 = Permute((2,1))(inp2)
    m2 = LSTM(20,input_shape=(20,50),stateful=True,batch_size=bsize,name='model2',recurrent_dropout=0.5)(input2)
    
    inp3 = Input(batch_shape=(bsize,50,20),name='input3')
    input3 = Permute((2,1))(inp3)
    m3 = LSTM(20,input_shape=(20,50),stateful=True,batch_size=bsize,name='model3',recurrent_dropout=0.5)(input3)
    
    inp4 = Input(batch_shape=(bsize,50,20),name='input4')
    input4 = Permute((2,1))(inp4)
    m4 = LSTM(20,input_shape=(20,50),stateful=True,batch_size=bsize,name='model4',recurrent_dropout=0.5)(input4)
    
    inp5 = Input(batch_shape=(bsize,50,20),name='input5')
    input5 = Permute((2,1))(inp5)
    m5 = LSTM(20,input_shape=(20,50),stateful=True,batch_size=bsize,name='model5',recurrent_dropout=0.5)(input5)
    
    inp = Input(batch_shape=(bsize,50,20),name='weight_model')
    input_c = Permute((2,1))(inp)
    w_model = LSTM(20,input_shape=(20,50),stateful=False,batch_size=bsize,recurrent_dropout=0.5)(input_c)
    w_model = Dense(5, activation='softmax')(w_model)
    w_model = Dropout(0.5)(w_model)
    merge_softmax = Reshape((1, 5))(w_model)
    
    merged = merge([m1, m2 ,m3 ,m4, m5],mode='concat')
    reshaped = Reshape((5, 20))(merged)
    
    final_merged = merge([reshaped, merge_softmax], mode = 'dot', dot_axes = [1, 2])
    reshaped2 = Reshape((20, ))(final_merged)

    
    reshaped2 = Dense(10)(reshaped2)
    reshaped2 = Dropout(0.5)(reshaped2)
    main_output = Dense(1, activation='sigmoid',name='main_output')(reshaped2)
    model = Model(inputs=[inp1,inp2,inp3,inp4,inp5,inp],outputs=[main_output])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(model.summary())
    #model.fit([X_train[0:length]], np.array(y_train)[0:length], nb_epoch=40, batch_size=bsize)
    return model

# %%
#folder_names = ["ferguson"]
folder_names = ["charliehebdo","ferguson","germanwings-crash","ottawashooting","sydneysiege"]
df_features,df_text = get_pd_frame_by_topics(folder_names)
all_labels = df_text['rumour_bool']
all_data = convert_text_to_tokens(df_text['text'],glove_model)
X_train, X_test, y_train, y_test = train_test_split(all_data, all_labels, test_size=0.33, random_state=42,shuffle = False)
bsize = 100
length_train =int(len(X_train)/bsize)*bsize
length_test =int(len(X_test)/bsize)*bsize
imp = X_train[0:length_train]
impt = X_test[0:length_test]
model = stacked_lstm(X_train,y_train,bsize)
#model.fit([imp,imp,imp,imp,imp,imp], np.array(y_train)[0:length], nb_epoch=30, batch_size=bsize)
history = model.fit([imp,imp,imp,imp,imp,imp], np.array(y_train)[0:length_train], nb_epoch=15, batch_size=bsize,validation_data=([impt,impt,impt,impt,impt,impt],y_test[0:length_test]))
import pickle
f = open('multilstm_context_stacked.pckl', 'wb')
pickle.dump(history.history, f)
f.close()
# Out:
# 30
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:34: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/dell/.local/lib/python3.5/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:37: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:14: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_6 (Permute)             (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_4 (Permute)             (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (100, 20)            5680        permute_6[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_1[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_2[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_3[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_4[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_5[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (100, 5)             105         lstm_1[0][0]
# __________________________________________________________________________________________________
# merge_1 (Merge)                 (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (100, 5)             0           dense_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (100, 5, 20)         0           merge_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (100, 1, 5)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# merge_2 (Merge)                 (100, 20, 1)         0           reshape_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (100, 20)            0           merge_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (100, 10)            210         reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (100, 10)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_2[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 3800 samples, validate on 1900 samples
# Epoch 1/15
# 3800/3800 [==============================] - 6s 2ms/step - loss: 0.6661 - acc: 0.6166 - val_loss: 0.6089 - val_acc: 0.6816
# Epoch 2/15
# 3800/3800 [==============================] - 4s 994us/step - loss: 0.6262 - acc: 0.6721 - val_loss: 0.5470 - val_acc: 0.7358
# Epoch 3/15
# 3800/3800 [==============================] - 4s 989us/step - loss: 0.5936 - acc: 0.6858 - val_loss: 0.5039 - val_acc: 0.7526
# Epoch 4/15
# 3800/3800 [==============================] - 4s 997us/step - loss: 0.5659 - acc: 0.7137 - val_loss: 0.4800 - val_acc: 0.7600
# Epoch 5/15
# 3800/3800 [==============================] - 4s 991us/step - loss: 0.5563 - acc: 0.7253 - val_loss: 0.4711 - val_acc: 0.7605
# Epoch 6/15
# 3800/3800 [==============================] - 4s 990us/step - loss: 0.5425 - acc: 0.7268 - val_loss: 0.4741 - val_acc: 0.7632
# Epoch 7/15
# 3800/3800 [==============================] - 4s 993us/step - loss: 0.5452 - acc: 0.7284 - val_loss: 0.4801 - val_acc: 0.7521
# Epoch 8/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.5268 - acc: 0.7400 - val_loss: 0.4723 - val_acc: 0.7700
# Epoch 9/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.5210 - acc: 0.7453 - val_loss: 0.4769 - val_acc: 0.7653
# Epoch 10/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.5059 - acc: 0.7532 - val_loss: 0.4745 - val_acc: 0.7711
# Epoch 11/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.5032 - acc: 0.7576 - val_loss: 0.4814 - val_acc: 0.7626
# Epoch 12/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.5037 - acc: 0.7526 - val_loss: 0.4764 - val_acc: 0.7742
# Epoch 13/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.4930 - acc: 0.7684 - val_loss: 0.4939 - val_acc: 0.7574
# Epoch 14/15
# 3800/3800 [==============================] - 4s 1ms/step - loss: 0.4839 - acc: 0.7668 - val_loss: 0.4998 - val_acc: 0.7521
# Epoch 15/15
# 3800/3800 [==============================] - 4s 996us/step - loss: 0.4843 - acc: 0.7700 - val_loss: 0.4895 - val_acc: 0.7658

# %%
#folder_names = ["ferguson"]
folder_names = ["charliehebdo","ferguson","germanwings-crash","ottawashooting","sydneysiege"]
df_features,df_text = get_pd_frame_by_topics(folder_names)
all_labels = df_text['rumour_bool']
all_data = convert_text_to_tokens(df_text['text'],glove_model)
X_train, X_test, y_train, y_test = train_test_split(all_data, all_labels, test_size=0.33, random_state=42,shuffle = False)
K = 5
accuracies = []
for i in range(5):
    X_train, X_test, y_train, y_test = train_test_split(all_data, all_labels, test_size=0.33,shuffle = False)
    bsize = 100
    length_train =int(len(X_train)/bsize)*bsize
    length_test =int(len(X_test)/bsize)*bsize
    model = stacked_lstm(X_train,y_train,bsize)
    imp = X_train[0:length_train]
    model.fit([imp,imp,imp,imp,imp,imp], np.array(y_train)[0:length_train], nb_epoch=15, batch_size=bsize)
    inp = X_test[0:length_test]
    loss,acc1 = model.evaluate([inp,inp,inp,inp,inp,inp],y_test[0:length_test],batch_size=bsize)
    accuracies.append(acc1)
# Out:
# 30
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:34: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/dell/.local/lib/python3.5/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:37: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/dell/.local/lib/python3.5/site-packages/ipykernel_launcher.py:16: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   app.launch_new_instance()
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_12 (Permute)            (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_8 (Permute)             (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_9 (Permute)             (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_10 (Permute)            (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_11 (Permute)            (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (100, 20)            5680        permute_12[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_7[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_8[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_9[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_10[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_11[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (100, 5)             105         lstm_2[0][0]
# __________________________________________________________________________________________________
# merge_3 (Merge)                 (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (100, 5)             0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (100, 5, 20)         0           merge_3[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (100, 1, 5)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# merge_4 (Merge)                 (100, 20, 1)         0           reshape_5[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (100, 20)            0           merge_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (100, 10)            210         reshape_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (100, 10)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_4[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3800/3800 [==============================] - 5s 1ms/step - loss: 0.6585 - acc: 0.6282
# Epoch 2/15
# 3800/3800 [==============================] - 3s 890us/step - loss: 0.6242 - acc: 0.6703
# Epoch 3/15
# 3800/3800 [==============================] - 3s 869us/step - loss: 0.5891 - acc: 0.6905
# Epoch 4/15
# 3800/3800 [==============================] - 3s 870us/step - loss: 0.5715 - acc: 0.7108
# Epoch 5/15
# 3800/3800 [==============================] - 3s 874us/step - loss: 0.5552 - acc: 0.7174
# Epoch 6/15
# 3800/3800 [==============================] - 3s 868us/step - loss: 0.5366 - acc: 0.7279
# Epoch 7/15
# 3800/3800 [==============================] - 3s 919us/step - loss: 0.5337 - acc: 0.7337
# Epoch 8/15
# 3800/3800 [==============================] - 3s 884us/step - loss: 0.5244 - acc: 0.7458
# Epoch 9/15
# 3800/3800 [==============================] - 4s 951us/step - loss: 0.5152 - acc: 0.7437
# Epoch 10/15
# 3800/3800 [==============================] - 3s 883us/step - loss: 0.5061 - acc: 0.7542
# Epoch 11/15
# 3800/3800 [==============================] - 3s 864us/step - loss: 0.5087 - acc: 0.7616
# Epoch 12/15
# 3800/3800 [==============================] - 3s 856us/step - loss: 0.4985 - acc: 0.7545
# Epoch 13/15
# 3800/3800 [==============================] - 3s 852us/step - loss: 0.4880 - acc: 0.7637
# Epoch 14/15
# 3800/3800 [==============================] - 3s 853us/step - loss: 0.4837 - acc: 0.7605
# Epoch 15/15
# 3800/3800 [==============================] - 3s 854us/step - loss: 0.4743 - acc: 0.7689
# 1900/1900 [==============================] - 1s 467us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_18 (Permute)            (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_13 (Permute)            (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_14 (Permute)            (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_17 (Permute)            (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (100, 20)            5680        permute_18[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_13[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_14[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_15[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_16[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_17[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (100, 5)             105         lstm_3[0][0]
# __________________________________________________________________________________________________
# merge_5 (Merge)                 (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (100, 5)             0           dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (100, 5, 20)         0           merge_5[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (100, 1, 5)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# merge_6 (Merge)                 (100, 20, 1)         0           reshape_8[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (100, 20)            0           merge_6[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (100, 10)            210         reshape_9[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (100, 10)            0           dense_6[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_6[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3800/3800 [==============================] - 5s 1ms/step - loss: 0.6519 - acc: 0.6318
# Epoch 2/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.6234 - acc: 0.6671
# Epoch 3/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5831 - acc: 0.6968
# Epoch 4/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5663 - acc: 0.7095
# Epoch 5/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5571 - acc: 0.7142
# Epoch 6/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5477 - acc: 0.7097
# Epoch 7/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5345 - acc: 0.7266
# Epoch 8/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5330 - acc: 0.7268
# Epoch 9/15
# 3800/3800 [==============================] - 3s 843us/step - loss: 0.5293 - acc: 0.7189
# Epoch 10/15
# 3800/3800 [==============================] - 3s 847us/step - loss: 0.5153 - acc: 0.7379
# Epoch 11/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5145 - acc: 0.7395
# Epoch 12/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5151 - acc: 0.7408
# Epoch 13/15
# 3800/3800 [==============================] - 3s 847us/step - loss: 0.4989 - acc: 0.7513
# Epoch 14/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.5003 - acc: 0.7524
# Epoch 15/15
# 3800/3800 [==============================] - 3s 853us/step - loss: 0.4769 - acc: 0.7629
# 1900/1900 [==============================] - 1s 513us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_24 (Permute)            (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_19 (Permute)            (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_20 (Permute)            (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_21 (Permute)            (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_22 (Permute)            (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_23 (Permute)            (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (100, 20)            5680        permute_24[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_19[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_20[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_21[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_22[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_23[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (100, 5)             105         lstm_4[0][0]
# __________________________________________________________________________________________________
# merge_7 (Merge)                 (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (100, 5)             0           dense_7[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (100, 5, 20)         0           merge_7[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (100, 1, 5)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# merge_8 (Merge)                 (100, 20, 1)         0           reshape_11[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (100, 20)            0           merge_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (100, 10)            210         reshape_12[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (100, 10)            0           dense_8[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_8[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3800/3800 [==============================] - 5s 1ms/step - loss: 0.6665 - acc: 0.6126
# Epoch 2/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.6297 - acc: 0.6608
# Epoch 3/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.6045 - acc: 0.6847
# Epoch 4/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.5823 - acc: 0.7039
# Epoch 5/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5569 - acc: 0.7163
# Epoch 6/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.5536 - acc: 0.7242
# Epoch 7/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.5422 - acc: 0.7266
# Epoch 8/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.5271 - acc: 0.7345
# Epoch 9/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.5131 - acc: 0.7566
# Epoch 10/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.5071 - acc: 0.7461
# Epoch 11/15
# 3800/3800 [==============================] - 3s 852us/step - loss: 0.5026 - acc: 0.7511
# Epoch 12/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.4923 - acc: 0.7571
# Epoch 13/15
# 3800/3800 [==============================] - 3s 847us/step - loss: 0.4881 - acc: 0.7645
# Epoch 14/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.4905 - acc: 0.7621
# Epoch 15/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.4813 - acc: 0.7684
# 1900/1900 [==============================] - 1s 568us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_30 (Permute)            (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_25 (Permute)            (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_26 (Permute)            (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_27 (Permute)            (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_28 (Permute)            (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_29 (Permute)            (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (100, 20)            5680        permute_30[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_25[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_26[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_27[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_28[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_29[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (100, 5)             105         lstm_5[0][0]
# __________________________________________________________________________________________________
# merge_9 (Merge)                 (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (100, 5)             0           dense_9[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (100, 5, 20)         0           merge_9[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (100, 1, 5)          0           dropout_9[0][0]
# __________________________________________________________________________________________________
# merge_10 (Merge)                (100, 20, 1)         0           reshape_14[0][0]
#                                                                  reshape_13[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (100, 20)            0           merge_10[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (100, 10)            210         reshape_15[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (100, 10)            0           dense_10[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_10[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3800/3800 [==============================] - 5s 1ms/step - loss: 0.6655 - acc: 0.6134
# Epoch 2/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.6364 - acc: 0.6568
# Epoch 3/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.6061 - acc: 0.6858
# Epoch 4/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.5643 - acc: 0.7208
# Epoch 5/15
# 3800/3800 [==============================] - 3s 858us/step - loss: 0.5566 - acc: 0.7208
# Epoch 6/15
# 3800/3800 [==============================] - 3s 854us/step - loss: 0.5421 - acc: 0.7300
# Epoch 7/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.5309 - acc: 0.7408
# Epoch 8/15
# 3800/3800 [==============================] - 3s 847us/step - loss: 0.5172 - acc: 0.7447
# Epoch 9/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.5105 - acc: 0.7500
# Epoch 10/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5101 - acc: 0.7482
# Epoch 11/15
# 3800/3800 [==============================] - 3s 847us/step - loss: 0.4965 - acc: 0.7608
# Epoch 12/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5042 - acc: 0.7524
# Epoch 13/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.4952 - acc: 0.7624
# Epoch 14/15
# 3800/3800 [==============================] - 3s 850us/step - loss: 0.4878 - acc: 0.7726
# Epoch 15/15
# 3800/3800 [==============================] - 3s 846us/step - loss: 0.4784 - acc: 0.7737
# 1900/1900 [==============================] - 1s 632us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# weight_model (InputLayer)       (100, 50, 20)        0
# __________________________________________________________________________________________________
# input1 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input3 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input4 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# input5 (InputLayer)             (100, 50, 20)        0
# __________________________________________________________________________________________________
# permute_36 (Permute)            (100, 20, 50)        0           weight_model[0][0]
# __________________________________________________________________________________________________
# permute_31 (Permute)            (100, 20, 50)        0           input1[0][0]
# __________________________________________________________________________________________________
# permute_32 (Permute)            (100, 20, 50)        0           input2[0][0]
# __________________________________________________________________________________________________
# permute_33 (Permute)            (100, 20, 50)        0           input3[0][0]
# __________________________________________________________________________________________________
# permute_34 (Permute)            (100, 20, 50)        0           input4[0][0]
# __________________________________________________________________________________________________
# permute_35 (Permute)            (100, 20, 50)        0           input5[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (100, 20)            5680        permute_36[0][0]
# __________________________________________________________________________________________________
# model1 (LSTM)                   (100, 20)            5680        permute_31[0][0]
# __________________________________________________________________________________________________
# model2 (LSTM)                   (100, 20)            5680        permute_32[0][0]
# __________________________________________________________________________________________________
# model3 (LSTM)                   (100, 20)            5680        permute_33[0][0]
# __________________________________________________________________________________________________
# model4 (LSTM)                   (100, 20)            5680        permute_34[0][0]
# __________________________________________________________________________________________________
# model5 (LSTM)                   (100, 20)            5680        permute_35[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (100, 5)             105         lstm_6[0][0]
# __________________________________________________________________________________________________
# merge_11 (Merge)                (100, 100)           0           model1[0][0]
#                                                                  model2[0][0]
#                                                                  model3[0][0]
#                                                                  model4[0][0]
#                                                                  model5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (100, 5)             0           dense_11[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (100, 5, 20)         0           merge_11[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (100, 1, 5)          0           dropout_11[0][0]
# __________________________________________________________________________________________________
# merge_12 (Merge)                (100, 20, 1)         0           reshape_17[0][0]
#                                                                  reshape_16[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (100, 20)            0           merge_12[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (100, 10)            210         reshape_18[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (100, 10)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (100, 1)             11          dropout_12[0][0]
# ==================================================================================================
# Total params: 34,406
# Trainable params: 34,406
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/15
# 3800/3800 [==============================] - 6s 1ms/step - loss: 0.6601 - acc: 0.6292
# Epoch 2/15
# 3800/3800 [==============================] - 3s 854us/step - loss: 0.6259 - acc: 0.6637
# Epoch 3/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.6013 - acc: 0.6737
# Epoch 4/15
# 3800/3800 [==============================] - 3s 861us/step - loss: 0.5749 - acc: 0.6918
# Epoch 5/15
# 3800/3800 [==============================] - 3s 848us/step - loss: 0.5607 - acc: 0.7139
# Epoch 6/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.5424 - acc: 0.7276
# Epoch 7/15
# 3800/3800 [==============================] - 3s 854us/step - loss: 0.5385 - acc: 0.7324
# Epoch 8/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.5219 - acc: 0.7345
# Epoch 9/15
# 3800/3800 [==============================] - 3s 853us/step - loss: 0.5133 - acc: 0.7458
# Epoch 10/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.5107 - acc: 0.7505
# Epoch 11/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.5016 - acc: 0.7600
# Epoch 12/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.4979 - acc: 0.7639
# Epoch 13/15
# 3800/3800 [==============================] - 3s 851us/step - loss: 0.4923 - acc: 0.7579
# Epoch 14/15
# 3800/3800 [==============================] - 3s 849us/step - loss: 0.4930 - acc: 0.7663
# Epoch 15/15
# 3800/3800 [==============================] - 3s 854us/step - loss: 0.4839 - acc: 0.7676
# 1900/1900 [==============================] - 1s 689us/step

# %%
print(np.mean(accuracies))
print(np.std(accuracies))
print(accuracies)
# Out:
# 0.75915789604187
# 0.006061552571609453
# [0.7605263120249698, 0.7689473785852131, 0.75, 0.7578947387243572, 0.7584210508748105]

# %%
bsize = 100
length =int(len(X_test)/bsize)*bsize
inp = X_test[0:length]
model.evaluate([inp,inp,inp,inp,inp,inp],y_test[0:length],batch_size=bsize)

# %%
folder_names = ["charliehebdo"]
#folder_names = ["charliehebdo","ferguson","germanwings-crash","ottawashooting","sydneysiege"]
df_features,df_text = get_pd_frame_by_topics(folder_names)
germanwingscrash_labels = df_text['rumour_bool']
germanwingscrash_data = convert_text_to_tokens(df_text['text'],glove_model)
bsize = 100
length =int(len(germanwingscrash_labels)/bsize)*bsize
inp = germanwingscrash_data[0:length]
X_train, X_test, y_train, y_test = train_test_split(germanwingscrash_data,germanwingscrash_labels, test_size=0.33, random_state=42,shuffle = False)
model = stacked_lstm(X_train,y_train,bsize)
bsize = 100
length =int(len(X_test)/bsize)*bsize
inp = X_test[0:length]
model.evaluate([inp,inp,inp,inp,inp,inp],y_test[0:length],batch_size=bsize)

# %%
folder_names = ["ferguson"]
#folder_names = ["charliehebdo","ferguson","germanwings-crash","ottawashooting","sydneysiege"]
df_features,df_text = get_pd_frame_by_topics(folder_names)
germanwingscrash_labels = df_text['rumour_bool']
germanwingscrash_data = convert_text_to_tokens(df_text['text'],glove_model)
bsize = 100
length =int(len(germanwingscrash_labels)/bsize)*bsize
inp = germanwingscrash_data[0:length]
X_train, X_test, y_train, y_test = train_test_split(germanwingscrash_data,germanwingscrash_labels, test_size=0.33, random_state=42,shuffle = False)
model = stacked_lstm(X_train,y_train,bsize)
bsize = 100
length =int(len(X_test)/bsize)*bsize
inp = X_test[0:length]
model.evaluate([inp,inp,inp,inp,inp,inp],y_test[0:length],batch_size=bsize)

# %%
# clf = RandomForestClassifier(max_depth=2)
# X_train, X_test, y_train, y_test = train_test_split(df, actual_labels, test_size=0.33, random_state=42)

# %%
# clf.fit(X_train, y_train)
# pred = clf.predict(X_test)
# print(accuracy_score(pred,y_test))

# %%
####next attempt

# %%
df_text['text']
# Out:
# 833     Customers in Sydney cafe taken hostage. Siege ...
# 740     RT @australian: Siege situation currently unfo...
# 946     Hostages held in Sydney cafe, Islamic flag see...
# 1218    UPDATE: Reports the Sydney Opera House has als...
# 1174    BREAKING NEWS: Hostage situation developing in...
# 131     Fingers crossed for Sydney. One day we won’t l...
# 932     Breaking: Reports that the Sydney Opera House ...
# 522     Be especially kind to each other today, Sydney...
# 864     Note: Flag held up by Sydney hostages is NOT t...
# 1192    #SydneySiege latest: Reports of an incident at...
# 1018    UPDATE: Airspace across Sydney is in lockdown....
# 819     BREAKING: Hostages held in downtown Sydney caf...
# 991     Hostages in Sydney cafe made to hold up Islami...
# 364     Do not forget that the overwhelming majority o...
# 876     UPDATE: Aerials are coming in from Sydney Oper...
# 914     BREAKING NEWS: Gunmen take hostages at Sydney ...
# 181     Thoughts and prayers with everyone involved in...
# 895     BREAKING NEWS: Gunmen take hostages at Sydney ...
# 37      There are no verses in the Quran about Me want...
# 959     Hostages held in Sydney cafe, Islamic flag see...
# 180     Sky News reporter @campricenews at the scene o...
# 1104    Flag in Sydney cafe where hostages are being h...
# 45      If you have any lingering doubts that the thre...
# 1137    For those confused: gunmen have taken hostages...
# 102     If there's a Sydney-style attack in the U.S. a...
# 708     Let us #pray for the hostages taken in #Martin...
# 878     Live Updates: Siege in Sydney Cafe http://t.co...
# 1210    Pray with me for those being held hostage righ...
# 972     Gunman takes several hostages in Sydney cafe, ...
# 403     Police outside the Lindt cafe in Martin Place....
#                               ...
# 1184    This is The Islamic State flag, not the one in...
# 1156    Flag in window of Sydney Lindt cafe not an ISI...
# 964     Flag in window of Sydney Lindt cafe not an ISI...
# 941     SYDNEY: Reports of people with their hands up ...
# 1050    Siege at Sydney's Martin Place has now been un...
# 893     This is flag currently held in Sydney window, ...
# 474     Careful what you post about #Lindt Sydney sieg...
# 699     Hostage situation in Sydney is happening next ...
# 842                                SYDNEY AIRSPACE CLOSED
# 1090    If I understand Hillary Clinton &amp; Sen Fein...
# 1150    #breaking  We have now heard that all airspace...
# 865     ISIS -holding a Cafe hostage in Sydney- forcin...
# 248     Every citizen of Sydney has an obligation to h...
# 815     #BREAKING Hostages held inside Sydney cafe, Is...
# 1188    There are reportedly 13 hostages in the siege ...
# 1151    Geoblock lifted on #ABCNews24. Streaming cover...
# 1085    Strange flag in #Sydney, not the one affiliate...
# 1204    Reportedly 13 hostages &amp; 2 or more gunmen ...
# 544     If you are in Sydney near Martin Place, do NOT...
# 1219    Update: Airspace over Sydney has been shut dow...
# 1105    Latest reports are that there 13 hostages bein...
# 690     I repeat=&gt;if you are in Sydney, do NOT twee...
# 1143    Hostages being held in Sydney, Australia cafe ...
# 770     Sydney Opera House has been completely evacuat...
# 485     What's happening in Sydney will happen in the ...
# 1024    UPDATE: Hostages in Sydney cafe brandishing bl...
# 813     Sydney siege: hostages held inside Martin Plac...
# 1032    BREAKING Hostages held in Sydney, Australia, c...
# 673     No one fully knows what is happening with the ...
# 426     DEVELOPING: Major police operation underway at...
# Name: text, Length: 1221, dtype: object
